# %%
import pandas as pd 
import numpy as np
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
# %matplotlib inline

# %%
X = np.random.rand(50,2)
Y = 2+ np.random.rand(50,2)
Z = np.concatenate((X,Y)) #joins a sequence of arrays along a axis
Z = pd.DataFrame(Z)
Z
# Out:
#            0         1
# 0   0.096527  0.319954
# 1   0.331979  0.033877
# 2   0.639292  0.550862
# 3   0.903595  0.900962
# 4   0.846701  0.387203
# ..       ...       ...
# 95  2.285511  2.518627
# 96  2.040326  2.758284
# 97  2.908644  2.795326
# 98  2.942651  2.126510
# 99  2.317901  2.055883
#
# [100 rows x 2 columns]

# %%
sns.scatterplot(Z[0],Z[1])
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %%
KMean = KMeans(n_clusters = 2)
KMean.fit(Z)
label = KMean.predict(Z)
# creates two clusters

# %%
print(f'Silhouette Score(n = 2):{silhouette_score(Z, label)}')
# Out:
# Silhouette Score(n = 2):0.7982301935628761
