# %% [markdown]
# WCSS: Within Cluster Sum of Squares
#
# Computed as the sigma of (X - Y)^2 , where Y is the centroid for the observation X.
#
# This method aims to maximize number of clusters. The smaller the distance the better is gets. Decrease in WCSS means increasing clustering performance.
#
# Can be used with elbow method and silhouette coefficient

# %% [markdown]
# ## Plain WCSS

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../../data/cleanData/oneEncodedDiscord.csv')
X = data.iloc[:,[6,7]].values

# %%
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
   kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
   kmeans.fit(X)
   #appending the WCSS to the list (kmeans.inertia_ returns the WCSS value for an initialized cluster)
   wcss.append(kmeans.inertia_)
print(wcss)
# Out:
# [4954.868421052633, 2625.9439775910364, 1496.0, 1114.175, 748.0753968253968, 618.0535714285716, 520.8333333333335, 415.21212121212136, 332.35, 265.5166666666667]

# %%
#Plotting The Elbow graph
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Point Graph')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
