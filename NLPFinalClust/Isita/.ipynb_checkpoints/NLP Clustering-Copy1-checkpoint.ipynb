# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import re

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from stemming.porter2 import stem

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tag.perceptron import PerceptronTagger

from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity

# %%
# tagger = PerceptronTagger()
# tagset = None
# def remove_grammar(review):
#     sentences = nltk.sent_tokenize(review)
#     sentences = [nltk.word_tokenize(sent) for sent in sentences]
#     print('sentences',sentences)
#     result_review = []
#     for sentence in sentences:
#         tagged_review = nltk.tag._pos_tag(sentence, tagset, tagger)
#         cp = nltk.RegexpParser(grammar)
#         result = cp.parse(tagged_review)
#         result_review.append(traverseTree(result))
#     return ''.join([word for word in result_review])

# def clean(text):
#     text = text.lower()
#     string = ''
    
#     text=re.sub(r"[-()\"#!@$%^&*{}?.,:]"," ",text)
#     text=re.sub(r"\s+"," ",text)
#     text=re.sub('[^A-Za-z0-9]+',' ', text)
    
#     text = remove_grammar(text)
    
#     for word in text.split():
#         if word not in stopwords:
#             string += WordNetLemmatizer().lemmatize(word, pos='v')+ ' '
    
#     return string

# %%
# hi = 'hi im trying my best'

# print(clean(hi))
# Out:
# sentences [['hi', 'im', 'trying', 'my', 'best']]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-15-2908cf68dba7> in <module>
#       1 hi = 'hi im trying my best'
#       2
# ----> 3 print(clean(hi))
#
# <ipython-input-14-1d8e067929a0> in clean(text)
#      21     text=re.sub('[^A-Za-z0-9]+',' ', text)
#      22
# ---> 23     text = remove_grammar(text)
#      24
#      25     for word in text.split():
#
# <ipython-input-14-1d8e067929a0> in remove_grammar(review)
#       7     result_review = []
#       8     for sentence in sentences:
# ----> 9         tagged_review = nltk.tag._pos_tag(sentence, tagset, tagger)
#      10         cp = nltk.RegexpParser(grammar)
#      11         result = cp.parse(tagged_review)
#
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/nltk/tag/__init__.py in _pos_tag(tokens, tagset, tagger, lang)
#     112     if lang not in ["eng", "rus"]:
#     113         raise NotImplementedError(
# --> 114             "Currently, NLTK pos_tag only supports English and Russian "
#     115             "(i.e. lang='eng' or lang='rus')"
#     116         )
#
# NotImplementedError: Currently, NLTK pos_tag only supports English and Russian (i.e. lang='eng' or lang='rus')

# %%
tagger = PerceptronTagger()
tagset = None
stop = nltk.corpus.stopwords
wordnet_lemmatizer = WordNetLemmatizer()

grammar = '''REMOVE: {<PRP><VBP>?<VBG><TO>?}
                         {<PRP><MD><VB><TO>}
                         {<VBZ><DT><JJ>}
                         {<MD><DT><NN>}
                         {<NNP><PRP><VBP>}
                         {<MD><PRP>}
                         {<NNP><PRP><VBP>}
                         {<WDT><MD>}
                         {<PRP><VBP><VBG><VB><DT>}
                         {<VBZ><DT><JJ>}
                         {<VBZ><EX><NN><PRP><VBP><TO><VB>}
                         {<DT><VBZ>}
                         {<PRP><VBP><VBG><TO>}
                         {<MD><VB><TO><VB>}
                         {<VBZ><EX><DT>}
                         {<VB><TO>}
                         {<VBZ>}
                         {<DT>}
                         {<EX>}
                         {<PRP><VBP>}
                         {<CD>}
                         {<PRP\$>}
                         {<PRP>}
                         {<TO>}
                         {<IN>}
                         {<VBP>}
                         {<CC>}
              '''

def stem_doc(x):
    red_text = [stem(word.strip()) for word in x.split(" ") if word.strip()!='']
    return ' '.join(red_text)

def lem(x):
    try:
        return wordnet_lemmatizer.lemmatize(x,pos='v')
    except:
        return x
        
def remove_url(x):
    return re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', '', x)

def cleanse_text(text):
    if text:
        text = remove_url(text)
        addl_txt = addl_clean_words(text)
        red_text = clean_words(addl_txt)
        
        no_gram = red_text
        try:
            no_gram = remove_grammar(red_text)
        except:
            no_gram = red_text
    
        #clean = ' '.join([i for i in no_gram.split() if i not in stop])
        if no_gram:
            clean = ' '.join([i for i in no_gram.split()])
            red_text = [lem(word) for word in clean.split(" ")]
            red_text = [stem(word) for word in clean.split(" ")]
            return clean_words(' '.join(red_text))
        else:
            return no_gram
    else:
        return text

def cleanse_text_guided(text):
    if text:
        text = remove_url(text)
        addl_txt = addl_clean_words(text)
        red_text = clean_words_guided(addl_txt)
        
        no_gram = red_text
        try:
            no_gram = remove_grammar(red_text)
        except:
            no_gram = red_text
    
        #clean = ' '.join([i for i in no_gram.split() if i not in stop])
        if no_gram:
            clean = ' '.join([i for i in no_gram.split()])
            red_text = [lem(word) for word in clean.split(" ")]
            red_text = [stem(word) for word in clean.split(" ")]
            return clean_words(' '.join(red_text))
        else:
            return no_gram
    else:
        return text

        
def addl_clean_words(words):
    # any additional data pre-processing
    words = words.replace('can\'t','cannot')
    words = words.replace('won\'t','would not')
    words = words.replace('doesn\'t','does not')
    return words
    
def clean_words(words):
    if words:
        words = remove_email(words)
        words = words.replace('\t',' ')
        words = words.replace(',',' ')
        words = words.replace(':',' ')
        words = words.replace(';',' ')
        words = words.replace('=',' ')
        #words = words.replace('\x92','') # apostrophe encoding
        words = words.replace('\x08','\\b') # \b is being treated as backspace
        #words = ''.join([i for i in words if not i.isdigit()])
        words = words.replace('_',' ')
        words = words.replace('(',' ')
        words = words.replace(')',' ')
        words = words.replace('+',' ')
        words = words.replace('-',' ')
        words = words.replace('`',' ')
        words = words.replace('\'',' ')
        words = words.replace('.',' ')
        words = words.replace('#',' ')
        words = words.replace('/',' ')
        words = words.replace('_',' ')
        words = words.replace('"',' ')
        return words.strip()
    return words

def clean_words_guided(words):
    if words:
        words = remove_email(words)
        words = words.replace('\t',' ')
        words = words.replace(',',' ')
        words = words.replace(':',' ')
        words = words.replace(';',' ')
        words = words.replace('=',' ')
        #words = words.replace('\x92','') # apostrophe encoding
        words = words.replace('\x08','\\b') # \b is being treated as backspace
        #words = ''.join([i for i in words if not i.isdigit()])
        words = words.replace('_',' ')
        words = words.replace('(',' ')
        words = words.replace(')',' ')
        words = words.replace('+',' ')
        words = words.replace('-',' ')
        words = words.replace('`',' ')
        words = words.replace('\'',' ')
        words = words.replace('.',' ')
        words = words.replace('#',' ')
        words = words.replace('/',' ')
        words = words.replace('_',' ')
        words = words.replace('"',' ')
        words = words.replace("'",' ')
        return words.strip()
    return words

    
def remove_grammar(review):
    sentences = nltk.sent_tokenize(review)
    sentences = [nltk.word_tokenize(sent) for sent in sentences]
    result_review = []
    for sentence in sentences:
        if sentences.strip():
            tagged_review = nltk.tag._pos_tag(sentence, tagset, tagger)
            cp = nltk.RegexpParser(grammar)
            result = cp.parse(tagged_review)
            result_review.append(traverseTree(result))
    return ''.join([word for word in result_review])
    
# Remove email
def remove_email(words):
    mod_words = ''
    if words:
        if words.strip():
            for word in words.split(' '):
                if (word.strip().lower()=='email') or (word.strip().lower()=='phn') or (word.strip().lower()=='phone') or (len(word.strip())<=1):
                    continue
                elif not re.match(r"[^@]+@[^@]+\.[^@]+", word.lower()):
                    mod_words = mod_words+' '+word
                #else:   
    else:
        return words
    return mod_words.strip()

# %%
cleanse_text(hi)
# Out:
# 'hi im tri my best'

# %%
import os

os.getcwd()
# Out:
# '/Users/admin/Desktop/tryhard/marketAnalysis/NLPFinalClust/Isita'

# %%
df1 = pd.read_csv('../RawClustersOldBios/okcupid_profiles.csv')

# %%
df1
# Out:
#        age     status sex orientation       body_type               diet  \
# 0       22     single   m    straight  a little extra  strictly anything
# 1       35     single   m    straight         average       mostly other
# 2       38  available   m    straight            thin           anything
# 3       23     single   m    straight            thin         vegetarian
# 4       29     single   m    straight        athletic                NaN
# ...    ...        ...  ..         ...             ...                ...
# 59941   59     single   f    straight             NaN                NaN
# 59942   24     single   m    straight             fit    mostly anything
# 59943   42     single   m    straight         average    mostly anything
# 59944   27     single   m    straight        athletic    mostly anything
# 59945   39     single   m         gay         average                NaN
#
#            drinks      drugs                          education  \
# 0        socially      never      working on college/university
# 1           often  sometimes              working on space camp
# 2        socially        NaN     graduated from masters program
# 3        socially        NaN      working on college/university
# 4        socially      never  graduated from college/university
# ...           ...        ...                                ...
# 59941    socially      never  graduated from college/university
# 59942       often  sometimes      working on college/university
# 59943  not at all      never     graduated from masters program
# 59944    socially      often      working on college/university
# 59945    socially        NaN     graduated from masters program
#
#                  ethnicity  ...  \
# 0             asian, white  ...
# 1                    white  ...
# 2                      NaN  ...
# 3                    white  ...
# 4      asian, black, other  ...
# ...                    ...  ...
# 59941                  NaN  ...
# 59942         white, other  ...
# 59943                asian  ...
# 59944         asian, black  ...
# 59945                white  ...
#
#                                                   essay0  \
# 0      about me:  i would love to think that i was so...
# 1      i am a chef: this is what that means. 1. i am ...
# 2      i'm not ashamed of much, but writing public te...
# 3              i work in a library and go to school. . .
# 4      hey how's it going? currently vague on the pro...
# ...                                                  ...
# 59941  vibrant, expressive, caring optimist. i love b...
# 59942  i'm nick. i never know what to write about mys...
# 59943  hello! i enjoy traveling, watching movies, and...
# 59944  "all i have in this world are my balls and my ...
# 59945  is it odd that having a little "enemy" status ...
#
#                                                   essay1  \
# 0      currently working as an international agent fo...
# 1      dedicating everyday to being an unbelievable b...
# 2      i make nerdy software for musicians, artists, ...
# 3              reading things written by old dead people
# 4                             work work work work + play
# ...                                                  ...
# 59941  the happiest times have been when life came to...
# 59942  currently finishing school for film production...
# 59943  i'm a civil engineer, who enjoys helping the c...
# 59944  following my dreams... "you got a dream... you...
# 59945  i work with elderly people (psychotherapy and ...
#
#                                                   essay2  \
# 0      making people laugh. ranting about a good salt...
# 1      being silly. having ridiculous amonts of fun w...
# 2      improvising in different contexts. alternating...
# 3      playing synthesizers and organizing books acco...
# 4      creating imagery to look at: http://bagsbrown....
# ...                                                  ...
# 59941  i make an outstanding osso bucco. i am also ve...
# 59942  filmmaking, photography, graphic design, web d...
# 59943  - looking at things objectively - getting thin...
# 59944                                          listening
# 59945  i'm a great bullshitter. i don't know what it ...
#
#                                                   essay3  \
# 0      the way i look. i am a six foot half asian, ha...
# 1                                                    NaN
# 2      my large jaw and large glasses are the physica...
# 3                      socially awkward but i do my best
# 4                i smile a lot and my inquisitive nature
# ...                                                  ...
# 59941  i am told that people notice my smile, eyes an...
# 59942                                dude, i don't know.
# 59943  i'm quiet until i get used to the environment ...
# 59944  it used to be the hair until i mowed it off bu...
# 59945  either that i am funny/sarcastic, or that i am...
#
#                                                   essay4  \
# 0      books: absurdistan, the republic, of mice and ...
# 1      i am die hard christopher moore fan. i don't r...
# 2      okay this is where the cultural matrix gets so...
# 3      bataille, celine, beckett. . . lynch, jarmusch...
# 4      music: bands, rappers, musicians at the moment...
# ...                                                  ...
# 59941  i am an avid movie watcher and follow the broa...
# 59942  movies: hook (the greatest adventure ever!), g...
# 59943  last book: "game change". movies: bourne serie...
# 59944  where to begin musically: right now i listen t...
# 59945  i just read the help by kathryn stockett, sooo...
#
#                                                   essay5  \
# 0                      food. water. cell phone. shelter.
# 1      delicious porkness in all of its glories. my b...
# 2      movement conversation creation contemplation t...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 59941         my family, my dog, italy, words and music!
# 59942  iphone contact lenses headphones camera tv rem...
# 59943  - iphone - friends and family - internet - bay...
# 59944  music, family, friends, a basketball, hoop, so...
# 59945  1. family & friends & other humans - interacti...
#
#                                                   essay6  \
# 0                            duality and humorous things
# 1                                                    NaN
# 2                                                    NaN
# 3                             cats and german philosophy
# 4                                                    NaN
# ...                                                  ...
# 59941                                   writing my book.
# 59942  i do most of my thinking on the bus to/from wo...
# 59943           aside from work, how to improve my home.
# 59944          what can i do to make someone chuckle....
# 59945  sex, myself, other people, how amazing everyth...
#
#                                                   essay7  \
# 0      trying to find someone to hang out with. i am ...
# 1                                                    NaN
# 2      viewing. listening. dancing. talking. drinking...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 59941  running with my dog, finishing up the work wee...
# 59942      bringin' home bacon, or drinking and shakin'!
# 59943    out enjoying friendly conversation over dinner.
# 59944  what i would do on any other day. everydays a ...
# 59945  out at happy hour with my friends, running int...
#
#                                                   essay8  \
# 0      i am new to california and looking for someone...
# 1      i am very open and will share just about anyth...
# 2      when i was five years old, i was known as "the...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 59941  i have a dream to sing at the alconquin in nyc...
# 59942  when i was 18 i got a tattoo of waldo somewher...
# 59943               please let me think about this more.
# 59944  i like walking around in other people's house ...
# 59945  i wish i could cry like holly hunter in broadc...
#
#                                                   essay9
# 0      you want to be swept off your feet! you are ti...
# 1                                                    NaN
# 2      you are bright, open, intense, silly, ironic, ...
# 3                                  you feel so inclined.
# 4                                                    NaN
# ...                                                  ...
# 59941  you are seeking a long term connection of shar...
# 59942     meh if you made it this far you might as well.
# 59943                         we have similar interests.
# 59944              you are interested and interesting...
# 59945  if you have a back-bone, an opinion, a sense o...
#
# [59946 rows x 31 columns]

# %%
df1 = df1.rename(columns={"essay0": "Bios"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-6c3bc7be29a4> in <module>
#       1 df1 = df1.rename(columns={"essay0": "Bios"})
# ----> 2 df1['Bios']=df1['Bios'].apply(cleanse_text)
#
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4210             else:
#    4211                 values = self.astype(object)._values
# -> 4212                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4213
#    4214         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-3-76ea0a52277b> in cleanse_text(text)
#      48 def cleanse_text(text):
#      49     if text:
# ---> 50         text = remove_url(text)
#      51         addl_txt = addl_clean_words(text)
#      52         red_text = clean_words(addl_txt)
#
# <ipython-input-3-76ea0a52277b> in remove_url(x)
#      44
#      45 def remove_url(x):
# ---> 46     return re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', '', x)
#      47
#      48 def cleanse_text(text):
#
# /opt/anaconda2/envs/cs185c/lib/python3.7/re.py in sub(pattern, repl, string, count, flags)
#     192     a callable, it's passed the Match object and must return
#     193     a replacement string to be used."""
# --> 194     return _compile(pattern, flags).sub(repl, string, count)
#     195
#     196 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
df1['Bios']=df1['Bios'].values.astype('U').apply(cleanse_text)

# features = vec.transform(df['bio'].values.astype('U'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-cafc666eccbe> in <module>
# ----> 1 df1['Bios']=df1['Bios'].apply(cleanse_text)
#
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4210             else:
#    4211                 values = self.astype(object)._values
# -> 4212                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4213
#    4214         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-3-76ea0a52277b> in cleanse_text(text)
#      48 def cleanse_text(text):
#      49     if text:
# ---> 50         text = remove_url(text)
#      51         addl_txt = addl_clean_words(text)
#      52         red_text = clean_words(addl_txt)
#
# <ipython-input-3-76ea0a52277b> in remove_url(x)
#      44
#      45 def remove_url(x):
# ---> 46     return re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', '', x)
#      47
#      48 def cleanse_text(text):
#
# /opt/anaconda2/envs/cs185c/lib/python3.7/re.py in sub(pattern, repl, string, count, flags)
#     192     a callable, it's passed the Match object and must return
#     193     a replacement string to be used."""
# --> 194     return _compile(pattern, flags).sub(repl, string, count)
#     195
#     196 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
df1['Bios']
# Out:
# 0     Internet nerd Award win coff trailblaz Social ...
# 1     Pop cultur trailblaz Coff maven Award win beer...
# 2     Problem solver Avid music buff Beer trailblaz ...
# 3     Evil social media lover Student Amateur thinke...
# 4     Friend problem solver Troublemak Subt charm so...
# 5     Beer geek Unapologet zombi ninja Award win mus...
# 6     Evil social media lover Student Amateur thinke...
# 7     Friend problem solver Troublemak Subt charm so...
# 8     Pop cultur geek Friend troublemak Student Weba...
# 9     Pop cultur trailblaz Coff maven Award win beer...
# 10    Avid coff geek Hipster friend twitter guru Fal...
# 11    Infuriat humbl zombi trailblaz Wannab tv ninja...
# 12    Pop cultur ninja Entrepreneur Profess writer C...
# 13    Avid coff geek Hipster friend twitter guru Fal...
# 14    Tv scholar Gener social media junki Extreme al...
# 15    Prone to fit of apathi Fall down lot Bacon gee...
# 16    Friend problem solver Troublemak Subt charm so...
# 17    Bacon advoc Troublemak Avid social media enthu...
# 18    Prone to fit of apathi Fall down lot Bacon gee...
# 19    Pop cultur trailblaz Coff maven Award win beer...
# 20    Avid coff geek Hipster friend twitter guru Fal...
# 21    Avid web specialist Lifelong zombi fan Tv trai...
# 22    Fall down lot Pop cultureahol Tv expert Intern...
# 23    Extreme introvert Twitter buff Evil social med...
# 24    Profess travel expert Problem solver Reader Fo...
# 25    Coff advoc Introvert Infuriat humbl beer nerd ...
# 26    Extreme introvert Twitter buff Evil social med...
# 27    Organiz Tvahol Explorer Proud communic Wannab ...
# 28    Amateur social media maven Pop cultureahol Tro...
# 29    Coff advoc Introvert Infuriat humbl beer nerd ...
# 30    Extreme introvert Twitter buff Evil social med...
# 31    Travel expert Introvert Pop cultur guru Profes...
# 32    Extreme coff enthusiast Lifelong alcohol guru ...
# 33    Extreme introvert Twitter buff Evil social med...
# 34    Student Hipster friend travel fanat Zombi guru...
# 35    Typic travel aficionado Extreme alcohol evange...
# 36    Fall down lot Pop cultureahol Tv expert Intern...
# 37    Organiz Tvahol Explorer Proud communic Wannab ...
# 38    Extreme coff enthusiast Lifelong alcohol guru ...
# 39    Zombieahol Commun Coff lover Wannab explor Pro...
# 40    Tv buff Fall down lot Profess pop cultur speci...
# 41    Travel expert Introvert Pop cultur guru Profes...
# 42    Coff advoc Introvert Infuriat humbl beer nerd ...
# 43    Profess travel expert Problem solver Reader Fo...
# 44    Typic travel aficionado Extreme alcohol evange...
# Name: Bios, dtype: object

# %%
vectorizer = CountVectorizer(analyzer='word',stop_words='english',decode_error='ignore',binary=True)    
    
counts = vectorizer.fit_transform(df1['Bios'])

# %%
from sklearn.metrics import silhouette_samples,silhouette_score, davies_bouldin_score
from sklearn.cluster import AgglomerativeClustering
n = 30

for cluster_num in range(2,n):
#     kmeans = KMeans(n_clusters=10,n_jobs=-1)
    
    hac = AgglomerativeClustering(n_clusters = cluster_num)
    labels = hac.fit_predict(counts.toarray())
    sil = silhouette_score(counts.toarray(), labels)
    db = davies_bouldin_score(counts.toarray(), labels)
    print('clus {}: {}, {}'.format(cluster_num, sil, db))
# Out:
# clus 2: 0.12207304161333878, 0.9169925009260752
# clus 3: 0.14429030773375967, 1.5245901847120844
# clus 4: 0.17274515923500525, 2.1087251289715496
# clus 5: 0.2127270774327061, 2.0606431798697527
# clus 6: 0.24732877171611725, 1.8692173412589843
# clus 7: 0.2976040439340036, 1.6444848045985803
# clus 8: 0.3434042424101895, 1.509522569324341
# clus 9: 0.40164208534275736, 1.3334035594742384
# clus 10: 0.46090134460201665, 1.1863830843825078
# clus 11: 0.5096317295574622, 1.1167421529952601
# clus 12: 0.5506100811091011, 1.09399865733298
# clus 13: 0.5793906360264066, 1.1746593959851357
# clus 14: 0.6066628043517414, 1.141135341777687
# clus 15: 0.6117350543368423, 1.1308779203627994
# clus 16: 0.6159718329068953, 1.0533045642716796
# clus 17: 0.6671871205232816, 0.9937706356137612
# clus 18: 0.6949958147929114, 0.9717567761955207
# clus 19: 0.6992387466269874, 0.9120895362152738
# clus 20: 0.7017572914435898, 0.8189064642990621
# clus 21: 0.7052216161067173, 0.7582423029123139
# clus 22: 0.7075676785289413, 0.7135172713082519
# clus 23: 0.7088114925615293, 0.6018176836328317
# clus 24: 0.7074844925679885, 0.5650143212659139
# clus 25: 0.7089197293081333, 0.4995665484637377
# clus 26: 0.7111111111111111, 0.0
# clus 27: 0.6666666666666666, 0.0
# clus 28: 0.6222222222222222, 0.0
# clus 29: 0.5777777777777777, 0.0

# %%
for cluster_num in range(2,n):
    kmeans = KMeans(n_clusters=10,n_jobs=-1)
    
#     hac = AgglomerativeClustering(n_clusters = cluster_num)
    labels = kmeans.fit_predict(counts.toarray())
    sil = silhouette_score(counts.toarray(), labels)
    db = davies_bouldin_score(counts.toarray(), labels)
    print('clus {}: {}, {}'.format(cluster_num, sil, db))
# Out:
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# clus 2: 0.39179567263128856, 1.3261213311980247
# clus 3: 0.40121610448856865, 1.3148985553140984
# clus 4: 0.39179567263128856, 1.3261213311980247
# clus 5: 0.3850869430594562, 1.3063133009730645
# clus 6: 0.39695290550949225, 1.2590366117358736
# clus 7: 0.40567471546457656, 1.3421103275899737
# clus 8: 0.39179567263128856, 1.3261213311980247
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# clus 9: 0.3861824699270198, 1.3338478691944995
# clus 10: 0.40566238819817146, 1.3396382326099312
# clus 11: 0.39589618404768195, 1.3693736994401933
# clus 12: 0.38113503953180244, 1.4456395066934062
# clus 13: 0.39296693220223955, 1.3490227732293085
# clus 14: 0.39945161506806487, 1.3473404570735017
# clus 15: 0.3727972213933558, 1.3876040205203728
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# clus 16: 0.3850869430594562, 1.3063133009730643
# clus 17: 0.3853260729541909, 1.3079160857800232
# clus 18: 0.39307378134620025, 1.363110841505004
# clus 19: 0.3912239781124687, 1.337365937065109
# clus 20: 0.39714135654714394, 1.292654456522563
# clus 21: 0.39927392523714755, 1.2905176247269874
# clus 22: 0.3938320360138223, 1.3923581156328897
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# /opt/anaconda2/envs/cs185c/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#   " removed in 1.0 (renaming of 0.25).", FutureWarning)
# clus 23: 0.39813921795354495, 1.2691770770732924
# clus 24: 0.40567471546457656, 1.3421103275899737
# clus 25: 0.39662043828245885, 1.3646406691005986
# clus 26: 0.41600167771744423, 1.256073172636458
# clus 27: 0.38852664332330633, 1.4002283865106278
# clus 28: 0.4060370101510312, 1.3148881760682216
# clus 29: 0.417945290809076, 1.3305766388726812

# %%
n = 10
hac = AgglomerativeClustering(n_clusters = n)
labels1 = hac.fit_predict(counts.toarray())
df1['cluster_num'] = labels

# %%
os.mkdir('nlp_clus')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-34-fa15ea4151ac> in <module>
# ----> 1 os.mkdir('nlp_clus')
#
# FileExistsError: [Errno 17] File exists: 'nlp_clus'

# %%
def please(df, labels, n, someWord):
    #df_ori = pd.read_csv(filepath)
    df['cluster_num'] = labels
    #os.mkdir(os.getcwd() + '/' + someWord)
    
    
    for cluster in range(n):
        yes = df[df['cluster_num'] == cluster]
        filename = '{}/{}.csv'.format(someWord, str(cluster))
        yes.to_csv(filename)
    return df

# %%
please(df1,labels1,n,'nlp_clus')
# Out:
#     Unnamed: 0  Unnamed: 0.1  \
# 0            4             4
# 1           10            10
# 2           22            22
# 3           43            43
# 4           50            50
# 5           75            75
# 6           88            88
# 7           95            95
# 8          113           113
# 9          115           115
# 10         122           122
# 11         126           126
# 12         136           136
# 13         137           137
# 14         147           147
# 15         153           153
# 16         155           155
# 17         159           159
# 18         168           168
# 19         175           175
# 20         182           182
# 21         212           212
# 22         225           225
# 23         230           230
# 24         231           231
# 25         244           244
# 26         245           245
# 27         249           249
# 28         251           251
# 29         259           259
# 30         260           260
# 31         288           288
# 32         295           295
# 33         305           305
# 34         307           307
# 35         308           308
# 36         345           345
# 37         369           369
# 38         370           370
# 39         373           373
# 40         374           374
# 41         378           378
# 42         379           379
# 43         381           381
# 44         383           383
#
#                                                  Bios  Year  Major_Dept  \
# 0   Internet nerd Award win coff trailblaz Social ...     3           2
# 1   Pop cultur trailblaz Coff maven Award win beer...     1           7
# 2   Problem solver Avid music buff Beer trailblaz ...     3           5
# 3   Evil social media lover Student Amateur thinke...     4           1
# 4   Friend problem solver Troublemak Subt charm so...     1           5
# 5   Beer geek Unapologet zombi ninja Award win mus...     3           4
# 6   Evil social media lover Student Amateur thinke...     2           2
# 7   Friend problem solver Troublemak Subt charm so...     3           7
# 8   Pop cultur geek Friend troublemak Student Weba...     3           2
# 9   Pop cultur trailblaz Coff maven Award win beer...     4           7
# 10  Avid coff geek Hipster friend twitter guru Fal...     4           4
# 11  Infuriat humbl zombi trailblaz Wannab tv ninja...     3           7
# 12  Pop cultur ninja Entrepreneur Profess writer C...     4           3
# 13  Avid coff geek Hipster friend twitter guru Fal...     3           7
# 14  Tv scholar Gener social media junki Extreme al...     4           7
# 15  Prone to fit of apathi Fall down lot Bacon gee...     2           1
# 16  Friend problem solver Troublemak Subt charm so...     3           5
# 17  Bacon advoc Troublemak Avid social media enthu...     4           7
# 18  Prone to fit of apathi Fall down lot Bacon gee...     1           4
# 19  Pop cultur trailblaz Coff maven Award win beer...     1           5
# 20  Avid coff geek Hipster friend twitter guru Fal...     3           7
# 21  Avid web specialist Lifelong zombi fan Tv trai...     2           2
# 22  Fall down lot Pop cultureahol Tv expert Intern...     2           4
# 23  Extreme introvert Twitter buff Evil social med...     1           2
# 24  Profess travel expert Problem solver Reader Fo...     3           8
# 25  Coff advoc Introvert Infuriat humbl beer nerd ...     2           6
# 26  Extreme introvert Twitter buff Evil social med...     1           6
# 27  Organiz Tvahol Explorer Proud communic Wannab ...     1           1
# 28  Amateur social media maven Pop cultureahol Tro...     1           6
# 29  Coff advoc Introvert Infuriat humbl beer nerd ...     1           1
# 30  Extreme introvert Twitter buff Evil social med...     2           4
# 31  Travel expert Introvert Pop cultur guru Profes...     4           5
# 32  Extreme coff enthusiast Lifelong alcohol guru ...     3           1
# 33  Extreme introvert Twitter buff Evil social med...     2           8
# 34  Student Hipster friend travel fanat Zombi guru...     2           2
# 35  Typic travel aficionado Extreme alcohol evange...     2           8
# 36  Fall down lot Pop cultureahol Tv expert Intern...     2           7
# 37  Organiz Tvahol Explorer Proud communic Wannab ...     1           6
# 38  Extreme coff enthusiast Lifelong alcohol guru ...     1           6
# 39  Zombieahol Commun Coff lover Wannab explor Pro...     3           3
# 40  Tv buff Fall down lot Profess pop cultur speci...     2           6
# 41  Travel expert Introvert Pop cultur guru Profes...     2           6
# 42  Coff advoc Introvert Infuriat humbl beer nerd ...     4           8
# 43  Profess travel expert Problem solver Reader Fo...     3           8
# 44  Typic travel aficionado Extreme alcohol evange...     2           3
#
#     Ambition  Goals  Music  Sports  Friday_Nights  School_balance  \
# 0          1      1      7       1              2               1
# 1          2      1     10       7              2               2
# 2          2      1      5       7              2               3
# 3          2      1      4       3              2               2
# 4          2      1      5       7              2               3
# 5          2      1      6      10              2               2
# 6          3      1      9       1              2               1
# 7          3      1      4       3              2               2
# 8          1      1      4       9              2               2
# 9          1      1      4       5              2               3
# 10         2      1      5       9              2               2
# 11         1      1      5       5              2               1
# 12         2      1      4       9              2               2
# 13         3      1      4       1              2               2
# 14         3      1      5       8              2               1
# 15         2      1      6       5              2               1
# 16         1      1      6       8              2               2
# 17         3      1     10       3              2               2
# 18         3      1      9      10              2               3
# 19         1      1      3       8              2               1
# 20         3      1      1       9              2               2
# 21         3      1      2       2              2               3
# 22         3      1      1       3              2               3
# 23         1      1      5       7              2               3
# 24         2      1      7       2              2               3
# 25         3      1     10       9              2               3
# 26         2      1      8       1              2               1
# 27         1      1      3       6              2               3
# 28         3      1      8       5              2               1
# 29         3      1      5       1              2               1
# 30         2      1      8       5              2               3
# 31         1      1      8       2              2               1
# 32         2      1      2       5              2               2
# 33         2      1      8       6              2               1
# 34         2      1     10       4              2               3
# 35         2      1     10       1              2               3
# 36         3      1      9       8              2               3
# 37         3      1      4       3              2               3
# 38         3      1      8       6              2               1
# 39         1      1      9       5              2               2
# 40         2      1      5       1              2               2
# 41         1      1      1       3              2               3
# 42         3      1      3       2              2               3
# 43         3      1     10       5              2               1
# 44         3      1      1       6              2               3
#
#     Movie_Genres  Social_Style  Transfer  cluster #  cluster_num
# 0              8             2         1          3            2
# 1              8             1         1          3            1
# 2              5             3         1          3            0
# 3              9             3         1          3            7
# 4              9             1         1          3            0
# 5              4             3         1          3            2
# 6              9             1         1          3            7
# 7              4             1         1          3            0
# 8              3             3         1          3            2
# 9              4             2         1          3            1
# 10             7             1         1          3            8
# 11             8             1         1          3            2
# 12             2             3         1          3            1
# 13            11             1         1          3            8
# 14             2             1         1          3            2
# 15             6             1         1          3            5
# 16            10             1         1          3            0
# 17             9             1         1          3            2
# 18             5             1         1          3            5
# 19             4             1         1          3            1
# 20             8             1         1          3            8
# 21            10             3         1          3            2
# 22             3             2         1          3            2
# 23             8             2         1          3            3
# 24             4             3         1          3            0
# 25             4             3         1          3            6
# 26            11             2         1          3            3
# 27             6             2         1          3            4
# 28             1             1         1          3            2
# 29             7             2         1          3            6
# 30             5             2         1          3            3
# 31            10             2         1          3            9
# 32            10             1         1          3            2
# 33             4             1         1          3            3
# 34             4             2         1          3            2
# 35            11             3         1          3            2
# 36             3             1         1          3            2
# 37             6             1         1          3            4
# 38             5             1         1          3            2
# 39             9             1         1          3            0
# 40            11             2         1          3            1
# 41             8             1         1          3            9
# 42             3             3         1          3            6
# 43             4             1         1          3            0
# 44             6             3         1          3            2

# %%
tfidf_vectorizer = TfidfVectorizer(analyzer='word',stop_words='english',decode_error='ignore',binary=True)    
    
tf_counts = vectorizer.fit_transform(df1['Bios'])

n = 30

for cluster_num in range(2,n):
#     kmeans = KMeans(n_clusters=10,n_jobs=-1)
    
    hac = AgglomerativeClustering(n_clusters = cluster_num)
    labels = hac.fit_predict(counts.toarray())
    sil = silhouette_score(counts.toarray(), labels)
    db = davies_bouldin_score(counts.toarray(), labels)
    print('clus {}: {}, {}'.format(cluster_num, sil, db))
# Out:
# clus 2: 0.12207304161333878, 0.9169925009260752
# clus 3: 0.14429030773375967, 1.5245901847120844
# clus 4: 0.17274515923500525, 2.1087251289715496
# clus 5: 0.2127270774327061, 2.0606431798697527
# clus 6: 0.24732877171611725, 1.8692173412589843
# clus 7: 0.2976040439340036, 1.6444848045985803
# clus 8: 0.3434042424101895, 1.509522569324341
# clus 9: 0.40164208534275736, 1.3334035594742384
# clus 10: 0.46090134460201665, 1.1863830843825078
# clus 11: 0.5096317295574622, 1.1167421529952601
# clus 12: 0.5506100811091011, 1.09399865733298
# clus 13: 0.5793906360264066, 1.1746593959851357
# clus 14: 0.6066628043517414, 1.141135341777687
# clus 15: 0.6117350543368423, 1.1308779203627994
# clus 16: 0.6159718329068953, 1.0533045642716796
# clus 17: 0.6671871205232816, 0.9937706356137612
# clus 18: 0.6949958147929114, 0.9717567761955207
# clus 19: 0.6992387466269874, 0.9120895362152738
# clus 20: 0.7017572914435898, 0.8189064642990621
# clus 21: 0.7052216161067173, 0.7582423029123139
# clus 22: 0.7075676785289413, 0.7135172713082519
# clus 23: 0.7088114925615293, 0.6018176836328317
# clus 24: 0.7074844925679885, 0.5650143212659139
# clus 25: 0.7089197293081333, 0.4995665484637377
# clus 26: 0.7111111111111111, 0.0
# clus 27: 0.6666666666666666, 0.0
# clus 28: 0.6222222222222222, 0.0
# clus 29: 0.5777777777777777, 0.0

# %%
n = 13
hac = AgglomerativeClustering(n_clusters = n)
labels1 = hac.fit_predict(counts.toarray())
df1['cluster_num'] = labels

os.mkdir('nlp_clus_tfidf')
please(df1,labels1,n,'nlp_clus_tfidf')
# Out:
#     Unnamed: 0  Unnamed: 0.1  \
# 0            4             4
# 1           10            10
# 2           22            22
# 3           43            43
# 4           50            50
# 5           75            75
# 6           88            88
# 7           95            95
# 8          113           113
# 9          115           115
# 10         122           122
# 11         126           126
# 12         136           136
# 13         137           137
# 14         147           147
# 15         153           153
# 16         155           155
# 17         159           159
# 18         168           168
# 19         175           175
# 20         182           182
# 21         212           212
# 22         225           225
# 23         230           230
# 24         231           231
# 25         244           244
# 26         245           245
# 27         249           249
# 28         251           251
# 29         259           259
# 30         260           260
# 31         288           288
# 32         295           295
# 33         305           305
# 34         307           307
# 35         308           308
# 36         345           345
# 37         369           369
# 38         370           370
# 39         373           373
# 40         374           374
# 41         378           378
# 42         379           379
# 43         381           381
# 44         383           383
#
#                                                  Bios  Year  Major_Dept  \
# 0   Internet nerd Award win coff trailblaz Social ...     3           2
# 1   Pop cultur trailblaz Coff maven Award win beer...     1           7
# 2   Problem solver Avid music buff Beer trailblaz ...     3           5
# 3   Evil social media lover Student Amateur thinke...     4           1
# 4   Friend problem solver Troublemak Subt charm so...     1           5
# 5   Beer geek Unapologet zombi ninja Award win mus...     3           4
# 6   Evil social media lover Student Amateur thinke...     2           2
# 7   Friend problem solver Troublemak Subt charm so...     3           7
# 8   Pop cultur geek Friend troublemak Student Weba...     3           2
# 9   Pop cultur trailblaz Coff maven Award win beer...     4           7
# 10  Avid coff geek Hipster friend twitter guru Fal...     4           4
# 11  Infuriat humbl zombi trailblaz Wannab tv ninja...     3           7
# 12  Pop cultur ninja Entrepreneur Profess writer C...     4           3
# 13  Avid coff geek Hipster friend twitter guru Fal...     3           7
# 14  Tv scholar Gener social media junki Extreme al...     4           7
# 15  Prone to fit of apathi Fall down lot Bacon gee...     2           1
# 16  Friend problem solver Troublemak Subt charm so...     3           5
# 17  Bacon advoc Troublemak Avid social media enthu...     4           7
# 18  Prone to fit of apathi Fall down lot Bacon gee...     1           4
# 19  Pop cultur trailblaz Coff maven Award win beer...     1           5
# 20  Avid coff geek Hipster friend twitter guru Fal...     3           7
# 21  Avid web specialist Lifelong zombi fan Tv trai...     2           2
# 22  Fall down lot Pop cultureahol Tv expert Intern...     2           4
# 23  Extreme introvert Twitter buff Evil social med...     1           2
# 24  Profess travel expert Problem solver Reader Fo...     3           8
# 25  Coff advoc Introvert Infuriat humbl beer nerd ...     2           6
# 26  Extreme introvert Twitter buff Evil social med...     1           6
# 27  Organiz Tvahol Explorer Proud communic Wannab ...     1           1
# 28  Amateur social media maven Pop cultureahol Tro...     1           6
# 29  Coff advoc Introvert Infuriat humbl beer nerd ...     1           1
# 30  Extreme introvert Twitter buff Evil social med...     2           4
# 31  Travel expert Introvert Pop cultur guru Profes...     4           5
# 32  Extreme coff enthusiast Lifelong alcohol guru ...     3           1
# 33  Extreme introvert Twitter buff Evil social med...     2           8
# 34  Student Hipster friend travel fanat Zombi guru...     2           2
# 35  Typic travel aficionado Extreme alcohol evange...     2           8
# 36  Fall down lot Pop cultureahol Tv expert Intern...     2           7
# 37  Organiz Tvahol Explorer Proud communic Wannab ...     1           6
# 38  Extreme coff enthusiast Lifelong alcohol guru ...     1           6
# 39  Zombieahol Commun Coff lover Wannab explor Pro...     3           3
# 40  Tv buff Fall down lot Profess pop cultur speci...     2           6
# 41  Travel expert Introvert Pop cultur guru Profes...     2           6
# 42  Coff advoc Introvert Infuriat humbl beer nerd ...     4           8
# 43  Profess travel expert Problem solver Reader Fo...     3           8
# 44  Typic travel aficionado Extreme alcohol evange...     2           3
#
#     Ambition  Goals  Music  Sports  Friday_Nights  School_balance  \
# 0          1      1      7       1              2               1
# 1          2      1     10       7              2               2
# 2          2      1      5       7              2               3
# 3          2      1      4       3              2               2
# 4          2      1      5       7              2               3
# 5          2      1      6      10              2               2
# 6          3      1      9       1              2               1
# 7          3      1      4       3              2               2
# 8          1      1      4       9              2               2
# 9          1      1      4       5              2               3
# 10         2      1      5       9              2               2
# 11         1      1      5       5              2               1
# 12         2      1      4       9              2               2
# 13         3      1      4       1              2               2
# 14         3      1      5       8              2               1
# 15         2      1      6       5              2               1
# 16         1      1      6       8              2               2
# 17         3      1     10       3              2               2
# 18         3      1      9      10              2               3
# 19         1      1      3       8              2               1
# 20         3      1      1       9              2               2
# 21         3      1      2       2              2               3
# 22         3      1      1       3              2               3
# 23         1      1      5       7              2               3
# 24         2      1      7       2              2               3
# 25         3      1     10       9              2               3
# 26         2      1      8       1              2               1
# 27         1      1      3       6              2               3
# 28         3      1      8       5              2               1
# 29         3      1      5       1              2               1
# 30         2      1      8       5              2               3
# 31         1      1      8       2              2               1
# 32         2      1      2       5              2               2
# 33         2      1      8       6              2               1
# 34         2      1     10       4              2               3
# 35         2      1     10       1              2               3
# 36         3      1      9       8              2               3
# 37         3      1      4       3              2               3
# 38         3      1      8       6              2               1
# 39         1      1      9       5              2               2
# 40         2      1      5       1              2               2
# 41         1      1      1       3              2               3
# 42         3      1      3       2              2               3
# 43         3      1     10       5              2               1
# 44         3      1      1       6              2               3
#
#     Movie_Genres  Social_Style  Transfer  cluster #  cluster_num
# 0              8             2         1          3            1
# 1              8             1         1          3            0
# 2              5             3         1          3            5
# 3              9             3         1          3            7
# 4              9             1         1          3           10
# 5              4             3         1          3            1
# 6              9             1         1          3            7
# 7              4             1         1          3           10
# 8              3             3         1          3            1
# 9              4             2         1          3            0
# 10             7             1         1          3            8
# 11             8             1         1          3            1
# 12             2             3         1          3            0
# 13            11             1         1          3            8
# 14             2             1         1          3            1
# 15             6             1         1          3           12
# 16            10             1         1          3           10
# 17             9             1         1          3            1
# 18             5             1         1          3           12
# 19             4             1         1          3            0
# 20             8             1         1          3            8
# 21            10             3         1          3            1
# 22             3             2         1          3           11
# 23             8             2         1          3            3
# 24             4             3         1          3            5
# 25             4             3         1          3            6
# 26            11             2         1          3            3
# 27             6             2         1          3            4
# 28             1             1         1          3            1
# 29             7             2         1          3            6
# 30             5             2         1          3            3
# 31            10             2         1          3            9
# 32            10             1         1          3            2
# 33             4             1         1          3            3
# 34             4             2         1          3            1
# 35            11             3         1          3            2
# 36             3             1         1          3           11
# 37             6             1         1          3            4
# 38             5             1         1          3            2
# 39             9             1         1          3            5
# 40            11             2         1          3            0
# 41             8             1         1          3            9
# 42             3             3         1          3            6
# 43             4             1         1          3            5
# 44             6             3         1          3            2
